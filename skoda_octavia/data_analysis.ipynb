# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {return false;}
# // Avoid scrollable output for many plots

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import itertools
import tqdm
import matplotlib.pyplot as plt

sns.set(font_scale=1.5)
name = 'Skoda Octavia'
df = pd.read_parquet('data_2020-Oct-12.parquet')
print('Number cars: {}'.format(df.shape[0]));
df.drop_duplicates(inplace=True)
print('Number cars: {}'.format(df.shape[0]));
#df["fuelTypeGasoline"] = df["fuelTypeGasoline"].astype(int)
#df["carTypeStationCar"] = df["carTypeStationCar"].astype(int)

df.head()
# Out:
# Number cars: 1184
# Number cars: 532
#                                        headline  year  odometer     price  \
# 0  Skoda Octavia 1,5 TSi 150 Style Combi DSG 5d  2020   13000.0  264900.0
# 1     Skoda Octavia 1,4 TSi 140 Elegance DSG 5d  2014   98000.0  139800.0
# 2           Skoda Octavia 1,2 TSi 110 Active 5d  2016  145000.0  128980.0
# 3     Skoda Octavia 1,5 TSi 150 Ambition DSG 5d  2020   10000.0  239900.0
# 5      Skoda Octavia 1,0 TSi 115 Style Combi 5d  2018   38000.0  199900.0
#
#                                          description  horsepower  \
# 0  Business Line,, 16" Alufælge, 2 Zone Klima, Pa...       150.0
# 1  !!SOLGT!!Candy White, 18" Originale Alufælge, ...       140.0
# 2  Moon White Metallic, Fartpilot, Navigation, Mu...       110.0
# 3  Metallak - Moon White, Aut.Gear/Tiptronic, Air...       150.0
# 5  BM. STYLE MODEL !! 16" Alufælge, 2 Zone Klima,...       115.0
#
#                   region  transmissionManual  fuelTypeGasoline  \
# 0  Syd- og Sønderjylland               False              True
# 1                    Fyn               False              True
# 2             Østjylland                True              True
# 3            Nordjylland               False              True
# 5   Syd- og Vestsjælland                True              True
#
#    carTypeStationCar engineSize      trim
# 0               True        1,5     Style
# 1              False        1,4  Elegance
# 2              False        1,2    Active
# 3              False        1,5  Ambition
# 5               True        1,0     Style

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [headline, year, odometer, price, description, horsepower, region, transmissionManual, fuelTypeGasoline, carTypeStationCar, engineSize, trim]
# Index: []

# %%
print('Number cars: {}'.format(df.shape[0]));
df = df[df.price < 400_000]
print('Number cars: {}'.format(df.shape[0]));
# Out:
# Number cars: 532
# Number cars: 530

# %%
df.describe()
# Out:
#               year       odometer          price  horsepower
# count   530.000000     530.000000     530.000000  530.000000
# mean   2015.701887  100575.749057  169924.279245  131.215094
# std       2.793084   62896.622242   66685.853632   25.636232
# min    2010.000000    1000.000000   49900.000000   86.000000
# 25%    2014.000000   51000.000000  119900.000000  105.000000
# 50%    2016.000000   98000.000000  164850.000000  122.000000
# 75%    2018.000000  146500.000000  219900.000000  150.000000
# max    2021.000000  281000.000000  369900.000000  245.000000

# %%
plt.rcParams["figure.figsize"] =(12,8)
ax = df['price'].plot.hist(bins=60, alpha=0.5);
ax.set_xlabel('Selling price [DKK]');
ax.set_title(f"Histogram of the selling price of the {df.shape[0]} {name}");

# %%
# Plot correlation matrix
corr = df.corr()
cmap=sns.diverging_palette(5, 250, as_cmap=True)
corr.style.background_gradient(cmap, axis=1).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_b4299886_0c96_11eb_a716_f35ac268f048row0_col0,#T_b4299886_0c96_11eb_a716_f35ac268f048row1_col1,#T_b4299886_0c96_11eb_a716_f35ac268f048row2_col2,#T_b4299886_0c96_11eb_a716_f35ac268f048row3_col3,#T_b4299886_0c96_11eb_a716_f35ac268f048row4_col4,#T_b4299886_0c96_11eb_a716_f35ac268f048row5_col5,#T_b4299886_0c96_11eb_a716_f35ac268f048row6_col6{
#             background-color:  #4479bb;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row0_col1,#T_b4299886_0c96_11eb_a716_f35ac268f048row1_col2,#T_b4299886_0c96_11eb_a716_f35ac268f048row2_col1,#T_b4299886_0c96_11eb_a716_f35ac268f048row3_col4,#T_b4299886_0c96_11eb_a716_f35ac268f048row4_col2,#T_b4299886_0c96_11eb_a716_f35ac268f048row5_col1,#T_b4299886_0c96_11eb_a716_f35ac268f048row6_col4{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row0_col2{
#             background-color:  #5887c1;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row0_col3{
#             background-color:  #b8c9e0;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row0_col4,#T_b4299886_0c96_11eb_a716_f35ac268f048row5_col6{
#             background-color:  #de6b82;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row0_col5{
#             background-color:  #f0e3e5;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row0_col6{
#             background-color:  #dbe2eb;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row1_col0{
#             background-color:  #d94865;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row1_col3{
#             background-color:  #e494a4;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row1_col4{
#             background-color:  #c3d1e4;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row1_col5{
#             background-color:  #e69ead;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row1_col6,#T_b4299886_0c96_11eb_a716_f35ac268f048row6_col0{
#             background-color:  #ecc8cf;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row2_col0{
#             background-color:  #5786c1;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row2_col3{
#             background-color:  #8eadd3;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row2_col4{
#             background-color:  #dd657d;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row2_col5{
#             background-color:  #f2eeef;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row2_col6{
#             background-color:  #c5d3e4;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row3_col0{
#             background-color:  #d5deea;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row3_col1{
#             background-color:  #d8405e;
#             color:  #f1f1f1;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row3_col2{
#             background-color:  #a6bdda;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row3_col5{
#             background-color:  #edcfd5;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row3_col6{
#             background-color:  #ecc6ce;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row4_col0{
#             background-color:  #da4e6a;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row4_col1{
#             background-color:  #d3dce9;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row4_col3{
#             background-color:  #de6c83;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row4_col5{
#             background-color:  #eed6db;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row4_col6{
#             background-color:  #e48fa0;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row5_col0{
#             background-color:  #e7a3b0;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row5_col2,#T_b4299886_0c96_11eb_a716_f35ac268f048row5_col4{
#             background-color:  #e8aab6;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row5_col3{
#             background-color:  #ecc3cb;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row6_col1{
#             background-color:  #dd5f78;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row6_col2{
#             background-color:  #f0e0e3;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row6_col3{
#             background-color:  #e8abb7;
#             color:  #000000;
#         }#T_b4299886_0c96_11eb_a716_f35ac268f048row6_col5{
#             background-color:  #db5570;
#             color:  #000000;
#         }</style><table id="T_b4299886_0c96_11eb_a716_f35ac268f048" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >year</th>        <th class="col_heading level0 col1" >odometer</th>        <th class="col_heading level0 col2" >price</th>        <th class="col_heading level0 col3" >horsepower</th>        <th class="col_heading level0 col4" >transmissionManual</th>        <th class="col_heading level0 col5" >fuelTypeGasoline</th>        <th class="col_heading level0 col6" >carTypeStationCar</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b4299886_0c96_11eb_a716_f35ac268f048level0_row0" class="row_heading level0 row0" >year</th>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row0_col1" class="data row0 col1" >-0.74</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row0_col2" class="data row0 col2" >0.90</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row0_col3" class="data row0 col3" >0.42</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row0_col4" class="data row0 col4" >-0.51</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row0_col5" class="data row0 col5" >0.06</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row0_col6" class="data row0 col6" >0.25</td>
#             </tr>
#             <tr>
#                         <th id="T_b4299886_0c96_11eb_a716_f35ac268f048level0_row1" class="row_heading level0 row1" >odometer</th>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row1_col0" class="data row1 col0" >-0.74</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row1_col2" class="data row1 col2" >-0.81</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row1_col3" class="data row1 col3" >-0.36</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row1_col4" class="data row1 col4" >0.34</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row1_col5" class="data row1 col5" >-0.31</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row1_col6" class="data row1 col6" >-0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_b4299886_0c96_11eb_a716_f35ac268f048level0_row2" class="row_heading level0 row2" >price</th>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row2_col0" class="data row2 col0" >0.90</td>
#                         <td id="T_b4299886_0c96_11eb_a716_f35ac268f048row2_col1" class="data row2 col1" >-0.81</td

# %%
sns.pairplot(df[['year', 'odometer', 'horsepower', 'price']].copy());

# %%
plt.rcParams["figure.figsize"] =(12,8)
customPalette = sns.set_palette(sns.color_palette(['#ffffd9','#edf8b1','#c7e9b4','#7fcdbb','#41b6c4','#1d91c0','#225ea8','#0c2c84']))
for hue in [
    'year',
    'horsepower',
    'transmissionManual',
    'fuelTypeGasoline',
    'carTypeStationCar',
    'trim',
    'engineSize',
    'region',
    ]:
    ax = sns.scatterplot(x="odometer", y="price", hue=df[hue].tolist(), data=df, palette='viridis')
    ax.set_ylabel('Selling price [DKK]');
    ax.set_xlabel('Odometer');
    ax.set_title(f'Selling price of {df.shape[0]} {name} colorcoded with {hue}');
    plt.show()

# %% [markdown]
# # Selected

# %%
# Find cars comparable to my own
selected_name = 'Skoda Octavia, Style, DSG, ~100.000 km'
df_selected = df[
    (df.odometer < 130000) &
    (df.odometer > 80000) &
    (df.trim == 'Style') &
    (df.transmissionManual == True)
    # (df.fuelTypeGasoline == False)
    # (df.carTypeStationCar == False)
]
print(f'Number of selected cars: {df_selected.shape[0]}')
df_selected.head()
# Out:
# Number of selected cars: 20
#                                      headline  year  odometer     price  \
# 55         Skoda Octavia 1,4 TSi 150 Style 5d  2016   83000.0  149900.0
# 62         Skoda Octavia 1,6 TDi 115 Style 5d  2018   94000.0  169800.0
# 87   Skoda Octavia 1,0 TSi 115 Style Combi 5d  2017   91000.0  179900.0
# 131  Skoda Octavia 1,4 TSi 150 Style Combi 5d  2016   91000.0  179900.0
# 153  Skoda Octavia 1,4 TSi 150 Style Combi 5d  2017   89000.0  179800.0
#
#                                            description  horsepower  \
# 55   2 ZONE KLIMA \nAPPLE CARPLAY\nANDROID AUTO\nPA...       150.0
# 62   1 EJER - FULD SERVICEBOG HOS SKODA - SOMMER/VI...       115.0
# 87   Usandsynligt Velholdt!!! \nPragteksemplar. Båd...       115.0
# 131  KONKTAKT OS FOR VIDEOFREMVISNING. Highlights:\...       150.0
# 153  Velkørende Stationcar Med Det Rette Udstyr, So...       150.0
#
#                     region  transmissionManual  fuelTypeGasoline  \
# 55              Østjylland                True              True
# 62    Syd- og Vestsjælland                True             False
# 87               København                True              True
# 131  Syd- og Sønderjylland                True              True
# 153                    Fyn                True              True
#
#      carTypeStationCar engineSize   trim
# 55               False        1,4  Style
# 62               False        1,6  Style
# 87                True        1,0  Style
# 131               True        1,4  Style
# 153               True        1,4  Style

# %%
df_selected.describe()
# Out:
#               year       odometer          price  horsepower
# count    20.000000      20.000000      20.000000   20.000000
# mean   2016.450000   97650.000000  168579.450000  132.500000
# std       0.759155   12205.585434   15370.102344   19.901071
# min    2016.000000   82000.000000  139500.000000  110.000000
# 25%    2016.000000   86750.000000  154900.000000  110.000000
# 50%    2016.000000   95000.000000  169944.500000  150.000000
# 75%    2017.000000  105500.000000  179900.000000  150.000000
# max    2018.000000  126000.000000  194500.000000  150.000000

# %%
# Plot correlation matrix
corr = df_selected[['year', 'odometer', 'price']].corr()
#sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, vmin=-1, vmax=1, cmap=cmap);
cmap=sns.diverging_palette(5, 250, as_cmap=True)
corr.style.background_gradient(cmap, axis=1).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_7f200354_0c97_11eb_a716_f35ac268f048row0_col0,#T_7f200354_0c97_11eb_a716_f35ac268f048row1_col1,#T_7f200354_0c97_11eb_a716_f35ac268f048row2_col2{
#             background-color:  #4479bb;
#             color:  #000000;
#         }#T_7f200354_0c97_11eb_a716_f35ac268f048row0_col1,#T_7f200354_0c97_11eb_a716_f35ac268f048row1_col0,#T_7f200354_0c97_11eb_a716_f35ac268f048row2_col1{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#         }#T_7f200354_0c97_11eb_a716_f35ac268f048row0_col2{
#             background-color:  #abc1dc;
#             color:  #000000;
#         }#T_7f200354_0c97_11eb_a716_f35ac268f048row1_col2{
#             background-color:  #db5570;
#             color:  #000000;
#         }#T_7f200354_0c97_11eb_a716_f35ac268f048row2_col0{
#             background-color:  #b4c7df;
#             color:  #000000;
#         }</style><table id="T_7f200354_0c97_11eb_a716_f35ac268f048" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >year</th>        <th class="col_heading level0 col1" >odometer</th>        <th class="col_heading level0 col2" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7f200354_0c97_11eb_a716_f35ac268f048level0_row0" class="row_heading level0 row0" >year</th>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row0_col1" class="data row0 col1" >-0.39</td>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row0_col2" class="data row0 col2" >0.59</td>
#             </tr>
#             <tr>
#                         <th id="T_7f200354_0c97_11eb_a716_f35ac268f048level0_row1" class="row_heading level0 row1" >odometer</th>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row1_col0" class="data row1 col0" >-0.39</td>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row1_col2" class="data row1 col2" >-0.28</td>
#             </tr>
#             <tr>
#                         <th id="T_7f200354_0c97_11eb_a716_f35ac268f048level0_row2" class="row_heading level0 row2" >price</th>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row2_col0" class="data row2 col0" >0.59</td>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row2_col1" class="data row2 col1" >-0.28</td>
#                         <td id="T_7f200354_0c97_11eb_a716_f35ac268f048row2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
df_selected.year.unique()
# Out:
# array([2016, 2018, 2017])

# %%
plt.rcParams["figure.figsize"] =(12,8)
customPalette = sns.set_palette(sns.color_palette(['#ffffd9','#edf8b1','#c7e9b4','#7fcdbb','#41b6c4','#1d91c0','#225ea8','#0c2c84']))
for hue in [
    'year',
    'horsepower',
    'transmissionManual',
    'fuelTypeGasoline',
    'carTypeStationCar',
    #'trim',
    #'engineSize',
    #'region',
    ]:
    ax = sns.scatterplot(x="odometer", y="price", hue=df_selected[hue].tolist(), data=df_selected,palette='viridis')
    ax.set_ylabel('Selling price [DKK]');
    ax.set_xlabel('Odometer');
    ax.set_title(f'Selling price of {df_selected.shape[0]} selected {selected_name} colorcoded with {hue}');
    plt.show()
