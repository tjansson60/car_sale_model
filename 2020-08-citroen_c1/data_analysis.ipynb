# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {return false;}
# // Avoid scrollable output for many plots

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import itertools
import tqdm
import matplotlib.pyplot as plt

sns.set(font_scale=1.5)
name = 'Citroen C1'
df = pd.read_parquet('data_2020-Aug-18.parquet')
print('Number cars: {}'.format(df.shape[0]));
df.head()
# Out:
# Number cars: 415
#                                 headline  year  odometer     price  \
# 0       Citroën C1 1,0 e-VTi 68 Scoop 5d  2015   62000.0   54900.0
# 1           Citroën C1 1,0i Exclusive 5d  2014  115000.0   39900.0
# 2       Citroën C1 1,0 e-VTi 68 Scoop 5d  2014   72000.0   51900.0
# 3  Citroën C1 1,0 VTi 72 VTR Airscape 5d  2019    7000.0  109900.0
# 4       Citroën C1 1,0 VTi 72 Triumph 5d  2020    4000.0   89900.0
#
#                                          description  horsepower     region  \
# 0  Airc., Fjernb. C.Lås, Kørecomputer, Infocenter...        68.0        Fyn
# 1  Netop Nu Kampagne <<, Køb Bil Uden Udbetaling,...        68.0        Fyn
# 2  C1 I Den Helt Rigtige Farve, Flot Ude Som Inde...        68.0  København
# 3  RIGTIG FIN LILLE SOMMERBIL, MED MULIGHED FOR V...        72.0        Fyn
# 4  Abs, 6 Airbags, Servo, Esp, Antispin, Fjernb. ...        72.0        Fyn
#
#    fuelType engineSize       trim
# 0  Gasoline        1,0      Scoop
# 1  Gasoline        1,0  Exclusive
# 2  Gasoline        1,0      Scoop
# 3  Gasoline        1,0        VTR
# 4  Gasoline        1,0    Triumph

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                       headline  year  odometer     price  \
# 311  Citroën C1 1,0 VTi 72 Triumph Airscape 5d  2020       NaN  127240.0
#
#                                            description  horsepower  \
# 311  Fjernb. C.Lås, Sædevarme, Højdejust. Forsæde, ...        72.0
#
#                     region  fuelType engineSize     trim
# 311  Syd- og Sønderjylland  Gasoline        1,0  Triumph

# %%
df.describe()
# Out:
#               year      odometer          price  horsepower
# count   415.000000  4.140000e+02     415.000000  415.000000
# mean   2014.281928  8.516184e+04   54694.134940   71.291566
# std       3.460618  1.100062e+05   22177.746923    5.562930
# min    2006.000000  1.000000e+03   14000.000000   54.000000
# 25%    2012.000000  3.625000e+04   36900.000000   68.000000
# 50%    2014.000000  7.700000e+04   52500.000000   68.000000
# 75%    2017.000000  1.170000e+05   69900.000000   72.000000
# max    2020.000000  2.010000e+06  127240.000000   82.000000

# %%
# Data clean
df.loc[df.odometer == 2010000.0, 'odometer'] = np.nan

# %%
df.describe()
# Out:
#               year       odometer          price  horsepower
# count   415.000000     413.000000     415.000000  415.000000
# mean   2014.281928   80501.213075   54694.134940   71.291566
# std       3.460618   55823.258347   22177.746923    5.562930
# min    2006.000000    1000.000000   14000.000000   54.000000
# 25%    2012.000000   36000.000000   36900.000000   68.000000
# 50%    2014.000000   77000.000000   52500.000000   68.000000
# 75%    2017.000000  117000.000000   69900.000000   72.000000
# max    2020.000000  281000.000000  127240.000000   82.000000

# %%
plt.rcParams["figure.figsize"] =(12,8)
ax = df['price'].plot.hist(bins=30, alpha=0.5);
ax.set_xlabel('Selling price [DKK]');
ax.set_title(f"Histogram of the selling price of the {df.shape[0]} {name}");

# %%
# Plot correlation matrix
corr = df.corr()
cmap=sns.diverging_palette(5, 250, as_cmap=True)
corr.style.background_gradient(cmap, axis=1).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col0,#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col1,#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col2,#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col3{
#             background-color:  #4479bb;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col1,#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col2,#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col1,#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col1{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col2{
#             background-color:  #5a88c3;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col3{
#             background-color:  #a4bede;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col0{
#             background-color:  #db4d69;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col3{
#             background-color:  #e78c9e;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col0{
#             background-color:  #5887c2;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col3{
#             background-color:  #a9c1e0;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col0{
#             background-color:  #bbcee6;
#             color:  #000000;
#         }#T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col2{
#             background-color:  #c6d6ea;
#             color:  #000000;
#         }</style><table id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >year</th>        <th class="col_heading level0 col1" >odometer</th>        <th class="col_heading level0 col2" >price</th>        <th class="col_heading level0 col3" >horsepower</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bdelevel0_row0" class="row_heading level0 row0" >year</th>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col1" class="data row0 col1" >-0.75</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col2" class="data row0 col2" >0.89</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow0_col3" class="data row0 col3" >0.52</td>
#             </tr>
#             <tr>
#                         <th id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bdelevel0_row1" class="row_heading level0 row1" >odometer</th>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col0" class="data row1 col0" >-0.75</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col2" class="data row1 col2" >-0.83</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow1_col3" class="data row1 col3" >-0.43</td>
#             </tr>
#             <tr>
#                         <th id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bdelevel0_row2" class="row_heading level0 row2" >price</th>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col0" class="data row2 col0" >0.89</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col1" class="data row2 col1" >-0.83</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow2_col3" class="data row2 col3" >0.47</td>
#             </tr>
#             <tr>
#                         <th id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bdelevel0_row3" class="row_heading level0 row3" >horsepower</th>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col0" class="data row3 col0" >0.52</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col1" class="data row3 col1" >-0.43</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col2" class="data row3 col2" >0.47</td>
#                         <td id="T_a40cb0f8_e19b_11ea_917d_bffceb5e5bderow3_col3" class="data row3 col3" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
sns.pairplot(df[['year', 'odometer', 'horsepower', 'price']].copy());

# %%
plt.rcParams["figure.figsize"] =(12,8)
customPalette = sns.set_palette(sns.color_palette(['#ffffd9','#edf8b1','#c7e9b4','#7fcdbb','#41b6c4','#1d91c0','#225ea8','#0c2c84']))
for hue in [
    'year',
    'horsepower',
    #'transmissionManual',
    #'fuelTypeGasoline',
    #'carTypeStationCar',
    'trim',
    'engineSize',
    'region']:
    ax = sns.scatterplot(x="odometer", y="price", hue=hue, data=df) #, palette=customPalette)
    ax.set_ylabel('Selling price [DKK]');
    ax.set_xlabel('Odometer');
    ax.set_title(f'Selling price of {df.shape[0]} {name} colorcoded with {hue}');
    plt.show()

# %% [markdown]
# # Selected

# %%
# Find cars comparable to my own
df_selected = df[
    (df.odometer < 90000) & 
    (df.odometer > 70000)
]
print(f'Number of selected cars: {df_selected.shape[0]}')
df_selected.head()
# Out:
# Number of selected cars: 59
#                                   headline  year  odometer    price  \
# 2         Citroën C1 1,0 e-VTi 68 Scoop 5d  2014   72000.0  51900.0
# 12       Citroën C1 1,0i Seduction Clim 5d  2013   88000.0  44900.0
# 13       Citroën C1 1,0i Seduction Clim 5d  2014   76000.0  44900.0
# 15  Citroën C1 1,0i Prestige Sensodrive 5d  2007   85000.0  34900.0
# 26       Citroën C1 1,0i Seduction Clim 5d  2012   81000.0  44900.0
#
#                                           description  horsepower  \
# 2   C1 I Den Helt Rigtige Farve, Flot Ude Som Inde...        68.0
# 12  DET BLÅ LYN!\nAirc., Fjernb. C.Lås, Startspærr...        68.0
# 13  Airc., Fjernb. C.Lås, Startspærre, El-Ruder, S...        68.0
# 15  Bemærk Aut. Gear, Lav Km, El-Ruder, Fjbt. Cent...        68.0
# 26  Abs, 4 Airbags, Servo, Fjernb. C.Lås, El-Ruder...        68.0
#
#                   region  fuelType engineSize       trim
# 2              København  Gasoline        1,0      Scoop
# 12          Nordsjælland  Gasoline        1,0  Seduction
# 13  Syd- og Vestsjælland  Gasoline        1,0  Seduction
# 15           Nordjylland  Gasoline        1,0   Prestige
# 26                   Fyn  Gasoline        1,0  Seduction

# %%
df_selected.describe()
# Out:
#               year      odometer         price  horsepower
# count    59.000000     59.000000     59.000000   59.000000
# mean   2013.322034  81542.372881  47377.457627   69.423729
# std       1.897736   4527.014826   8914.564331    4.267776
# min    2007.000000  72000.000000  33900.000000   68.000000
# 25%    2012.000000  79000.000000  39900.000000   68.000000
# 50%    2013.000000  82000.000000  49500.000000   68.000000
# 75%    2015.000000  85000.000000  52690.000000   68.000000
# max    2017.000000  89000.000000  64990.000000   82.000000

# %%
# Plot correlation matrix
corr = df_selected[['year', 'odometer', 'price']].corr()
#sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, vmin=-1, vmax=1, cmap=cmap);
cmap=sns.diverging_palette(5, 250, as_cmap=True)
corr.style.background_gradient(cmap, axis=1).set_precision(2)
# Out:
# <style  type="text/css" >
# #T_a59e3496_e19b_11ea_917d_bffceb5e5bderow0_col0,#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow1_col1,#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow2_col2{
#             background-color:  #4479bb;
#             color:  #000000;
#         }#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow0_col1,#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow1_col0,#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow2_col1{
#             background-color:  #d73c5b;
#             color:  #f1f1f1;
#         }#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow0_col2{
#             background-color:  #81a4d1;
#             color:  #000000;
#         }#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow1_col2{
#             background-color:  #dd5a74;
#             color:  #000000;
#         }#T_a59e3496_e19b_11ea_917d_bffceb5e5bderow2_col0{
#             background-color:  #87a9d3;
#             color:  #000000;
#         }</style><table id="T_a59e3496_e19b_11ea_917d_bffceb5e5bde" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >year</th>        <th class="col_heading level0 col1" >odometer</th>        <th class="col_heading level0 col2" >price</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a59e3496_e19b_11ea_917d_bffceb5e5bdelevel0_row0" class="row_heading level0 row0" >year</th>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow0_col1" class="data row0 col1" >-0.21</td>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow0_col2" class="data row0 col2" >0.79</td>
#             </tr>
#             <tr>
#                         <th id="T_a59e3496_e19b_11ea_917d_bffceb5e5bdelevel0_row1" class="row_heading level0 row1" >odometer</th>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow1_col0" class="data row1 col0" >-0.21</td>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow1_col2" class="data row1 col2" >-0.11</td>
#             </tr>
#             <tr>
#                         <th id="T_a59e3496_e19b_11ea_917d_bffceb5e5bdelevel0_row2" class="row_heading level0 row2" >price</th>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow2_col0" class="data row2 col0" >0.79</td>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow2_col1" class="data row2 col1" >-0.11</td>
#                         <td id="T_a59e3496_e19b_11ea_917d_bffceb5e5bderow2_col2" class="data row2 col2" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
df_selected.year.unique()
# Out:
# array([2014, 2013, 2007, 2012, 2015, 2016, 2011, 2017, 2008, 2010])

# %%
plt.rcParams["figure.figsize"] = (12,8)

ax = sns.scatterplot(
    x="odometer",
    y="price",
    hue="year",
    data=df_selected,
    #palette=sns.color_palette("colorblind"),
    #size="horsepower"
)
ax.set_title(f'{name} selected');

# %%
plt.rcParams["figure.figsize"] =(12,8)
customPalette = sns.set_palette(sns.color_palette(['#ffffd9','#edf8b1','#c7e9b4','#7fcdbb','#41b6c4','#1d91c0','#225ea8','#0c2c84']))
for hue in [
    'year',
    'horsepower',
    #'transmissionManual',
    #'fuelTypeGasoline',
    #'carTypeStationCar',
    'trim',
    'engineSize',
    'region']:
    ax = sns.scatterplot(x="odometer", y="price", hue=hue, data=df_selected) #, palette=customPalette)
    ax.set_ylabel('Selling price [DKK]');
    ax.set_xlabel('Odometer');
    ax.set_title(f'Selling price of {df_selected.shape[0]} selected {name} colorcoded with {hue}');
    plt.show()
